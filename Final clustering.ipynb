# %%
import numpy as np
import pandas as pd

# %%
tor = pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')[0]
tor.head(5)
# Out:
#   Postalcode           Borough                Neighborhood
# 0        M1A      Not assigned                         NaN
# 1        M2A      Not assigned                         NaN
# 2        M3A        North York                   Parkwoods
# 3        M4A        North York            Victoria Village
# 4        M5A  Downtown Toronto  Regent Park / Harbourfront

# %%
tor.shape
# Out:
# (180, 3)

# %%
#Dropping cells where Borough is 'Not Assigned'
tor.drop(tor[tor['Borough'] =='Not assigned'].index, inplace = True)
tor.shape
# Out:
# (103, 3)

# %%
tor.reset_index(drop=True,inplace=True)
tor.head(20)
# Out:
#    Postalcode           Borough  \
# 0         M3A        North York
# 1         M4A        North York
# 2         M5A  Downtown Toronto
# 3         M6A        North York
# 4         M7A  Downtown Toronto
# 5         M9A         Etobicoke
# 6         M1B       Scarborough
# 7         M3B        North York
# 8         M4B         East York
# 9         M5B  Downtown Toronto
# 10        M6B        North York
# 11        M9B         Etobicoke
# 12        M1C       Scarborough
# 13        M3C        North York
# 14        M4C         East York
# 15        M5C  Downtown Toronto
# 16        M6C              York
# 17        M9C         Etobicoke
# 18        M1E       Scarborough
# 19        M4E      East Toronto
#
#                                          Neighborhood
# 0                                           Parkwoods
# 1                                    Victoria Village
# 2                          Regent Park , Harbourfront
# 3                   Lawrence Manor , Lawrence Heights
# ...

# %%
(tor['Postalcode'].value_counts()>1).sum() #Postal codes have no repeating values. But multiple neighborhoods having same codes are already grouped in same row.
# Out:
# 0

# %% [markdown]
# Also we can see that multiple neighborhoods in one borough are already combined with '/'. We shall convert '/' to ',' .

# %%
#Converting / to , in Neighborhood column
tor['Neighborhood']=tor['Neighborhood'].str.replace('/',',')
tor.head(5)
# Out:
#   Postalcode           Borough                                  Neighborhood
# 0        M3A        North York                                     Parkwoods
# 1        M4A        North York                              Victoria Village
# 2        M5A  Downtown Toronto                    Regent Park , Harbourfront
# 3        M6A        North York             Lawrence Manor , Lawrence Heights
# 4        M7A  Downtown Toronto  Queen's Park , Ontario Provincial Government

# %%
tor['Neighborhood'].isnull().sum()
#All neighborhood rows are filled. All boroughs are assigned some neighborhood.
# Out:
# 0

# %%
tor[tor['Neighborhood']=="Not assigned"]
#No neighborhood is in the 'Not assigned' category
# Out:
# Empty DataFrame
# Columns: [Postalcode, Borough, Neighborhood]
# Index: []

# %%
#Let us print the shape of the dataframe

tor.shape
# Out:
# (103, 3)

# %%
#Loading the csv file containing coordinates of all Postal codes
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
client_44b9055e0254400bb0f58ff48a6f656d = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='sIFfGLJ2NEnej2CC6AW-vcW_mM34z8mKCX6ih6EiJAKs',
    ibm_auth_endpoint="https://iam.eu-gb.bluemix.net/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.eu-geo.objectstorage.service.networklayer.com')

body = client_44b9055e0254400bb0f58ff48a6f656d.get_object(Bucket='segmentationandclusteringofneighb-donotdelete-pr-hw2gcg2u7zasng',Key='Geospatial_Coordinates.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

# If you are reading an Excel file into a pandas DataFrame, replace `read_csv` by `read_excel` in the next statement.
coord= pd.read_csv(body)
coord.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
coord=coord.rename(index=str, columns={"Postal Code": "Postalcode"})

# %%
coord.head()
# Out:
#   Postalcode   Latitude  Longitude
# 0        M1B  43.806686 -79.194353
# 1        M1C  43.784535 -79.160497
# 2        M1E  43.763573 -79.188711
# 3        M1G  43.770992 -79.216917
# 4        M1H  43.773136 -79.239476

# %%
toro=pd.merge(tor,coord, on="Postalcode")

# %%
toro.head()
# Out:
#   Postalcode           Borough                                  Neighborhood  \
# 0        M3A        North York                                     Parkwoods
# 1        M4A        North York                              Victoria Village
# 2        M5A  Downtown Toronto                    Regent Park , Harbourfront
# 3        M6A        North York             Lawrence Manor , Lawrence Heights
# 4        M7A  Downtown Toronto  Queen's Park , Ontario Provincial Government
#
#     Latitude  Longitude
# 0  43.753259 -79.329656
# 1  43.725882 -79.315572
# 2  43.654260 -79.360636
# 3  43.718518 -79.464763
# 4  43.662301 -79.389494

# %% [raw]
# Installing and importing required libraries

# %%
# !pip install geopy

# %%
# !pip install folium
# Out:
# ...
#      |████████████████████████████████| 92kB 7.0MB/s eta 0:00:011
# ...

# %%
from geopy.geocoders import Nominatim
import folium

# %%
address = 'Toronto,TO'

geolocator = Nominatim(user_agent="toro")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto city are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto city are 43.6534817, -79.3839347.

# %%
# create map of New York using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(toro['Latitude'], toro['Longitude'], toro['Borough'], toro['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Now we have plotted a map with all neighborhoods with boroughs in Toronto

# %% [markdown]
# Let's explore Buroughs having the word 'Toronto'

# %%
toro['Borough'].value_counts()
# Out:
# North York          24
# Downtown Toronto    19
# Scarborough         17
# Etobicoke           12
# Central Toronto      9
# West Toronto         6
# East Toronto         5
# York                 5
# East York            5
# Mississauga          1
# Name: Borough, dtype: int64

# %%
toro_boro = toro[(toro.Borough == 'Downtown Toronto') | (toro.Borough == 'Central Toronto') | (toro.Borough == 'West Toronto') | (toro.Borough  == 'East Toronto')]

# %%
toro_boro.head()
# Out:
#    Postalcode           Borough                                  Neighborhood  \
# 2         M5A  Downtown Toronto                    Regent Park , Harbourfront
# 4         M7A  Downtown Toronto  Queen's Park , Ontario Provincial Government
# 9         M5B  Downtown Toronto                     Garden District , Ryerson
# 15        M5C  Downtown Toronto                                St. James Town
# 19        M4E      East Toronto                                   The Beaches
#
#      Latitude  Longitude
# 2   43.654260 -79.360636
# 4   43.662301 -79.389494
# 9   43.657162 -79.378937
# 15  43.651494 -79.375418
# 19  43.676357 -79.293031

# %%
toro_boro['Borough'].value_counts()
# Out:
# Downtown Toronto    19
# Central Toronto      9
# West Toronto         6
# East Toronto         5
# Name: Borough, dtype: int64

# %%
#Let's visualize Downtown Toronto which has the most neighborhoods

# %%
doto=toro_boro[toro_boro['Borough']=='Downtown Toronto']

# %%
address = 'Central Toronto, TO'

geolocator = Nominatim(user_agent="doto")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Downtown Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Downtown Toronto are 43.6534817, -79.3839347.

# %%
#visualizing Downtown Toronto
map_doto = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(doto['Latitude'], doto['Longitude'], doto['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_doto)  
    
map_doto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #Clustering

# %%
from sklearn.cluster import KMeans
import matplotlib.cm as cm
import matplotlib.colors as colors

# %%
toro_clust=toro.drop('Neighborhood',axis=1)

# %%
toro_clust.head()
# Out:
#   Postalcode           Borough   Latitude  Longitude
# 0        M3A        North York  43.753259 -79.329656
# 1        M4A        North York  43.725882 -79.315572
# 2        M5A  Downtown Toronto  43.654260 -79.360636
# 3        M6A        North York  43.718518 -79.464763
# 4        M7A  Downtown Toronto  43.662301 -79.389494

# %%
toro_clust_onehot = pd.get_dummies(toro_clust[['Borough']], prefix="", prefix_sep="")

# %%
toro_clust_onehot['Latitude']=toro_clust['Latitude']
toro_clust_onehot['Longitude']=toro_clust['Longitude']

# %%
kclusters = 5

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toro_clust_onehot)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([2, 2, 1, 2, 1, 0, 3, 2, 4, 1], dtype=int32)

# %%
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

manhattan_merged = manhattan_data

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
manhattan_merged = manhattan_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

manhattan_merged.head() # check the last columns!

# %%
toro_clust_onehot.insert(0,'Kmean label',kmeans.labels_)

# %%
toro.insert(0,'Kmean label',kmeans.labels_)

# %%
toro.head()
# Out:
#    Kmean label Postalcode           Borough  \
# 0            2        M3A        North York
# 1            2        M4A        North York
# 2            1        M5A  Downtown Toronto
# 3            2        M6A        North York
# 4            1        M7A  Downtown Toronto
#
#                                    Neighborhood   Latitude  Longitude
# 0                                     Parkwoods  43.753259 -79.329656
# 1                              Victoria Village  43.725882 -79.315572
# 2                    Regent Park , Harbourfront  43.654260 -79.360636
# 3             Lawrence Manor , Lawrence Heights  43.718518 -79.464763
# 4  Queen's Park , Ontario Provincial Government  43.662301 -79.389494

# %%
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toro['Latitude'],toro['Longitude'], toro['Neighborhood'], toro['Kmean label']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Thus we have clustered the neighborhoods in the four Boroughs ending with 'Toronto' into 5 beautiful groups
